# %% [markdown]
# [![Roboflow Notebooks](https://media.roboflow.com/notebooks/template/bannertest2-2.png?ik-sdk-version=javascript-1.4.3&updatedAt=1672932710194)](https://github.com/roboflow/notebooks)
#
# # How to Train RF-DETR Object Detection on a Custom Dataset
#
# ---
#
# [![hf space](https://img.shields.io/badge/%F0%9F%A4%97%20Hugging%20Face-Spaces-blue)](https://huggingface.co/spaces/SkalskiP/RF-DETR)
# [![colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/roboflow-ai/notebooks/blob/main/notebooks/how-to-finetune-rf-detr-on-detection-dataset.ipynb)
# [![roboflow](https://raw.githubusercontent.com/roboflow-ai/notebooks/main/assets/badges/roboflow-blogpost.svg)](https://blog.roboflow.com/rf-detr)
# [![code](https://badges.aleen42.com/src/github.svg)](https://github.com/roboflow/rf-detr)
#
# RF-DETR is a real-time, transformer-based object detection model architecture developed by Roboflow and released under the Apache 2.0 license.
#
# ![rf-detr-coco-rf100-vl-8](https://media.roboflow.com/rf-detr/charts.png)
#
# RF-DETR is the first real-time model to exceed 60 AP on the [Microsoft COCO benchmark](https://cocodataset.org/#home) alongside competitive performance at base sizes. It also achieves state-of-the-art performance on [RF100-VL](https://github.com/roboflow/rf100-vl), an object detection benchmark that measures model domain adaptability to real world problems. RF-DETR is comparable speed to current real-time objection models.
#
# ![rf-detr-coco-results-2](https://media.roboflow.com/rf-detr/example_grid.png)
#
# RF-DETR is small enough to run on the edge, making it an ideal model for deployments that need both strong accuracy and real-time performance.

# %% [markdown]
# ## Environment setup

# %% [markdown]
# ### Configure API keys
#
# To fine-tune RF-DETR, you need to provide your Roboflow API key. Follow these steps:
#
# - Open your [`HuggingFace Settings`](https://huggingface.co/settings) page. Click `Access Tokens` then `New Token` to generate new token.
# - Go to your [`Roboflow Settings`](https://app.roboflow.com/settings/api) page. Click `Copy`. This will place your private key in the clipboard.
# - In Colab, go to the left pane and click on `Secrets` (🔑).
#     - Store HuggingFace Access Token under the name `HF_TOKEN`.
#     - Store Roboflow API Key under the name `ROBOFLOW_API_KEY`.

# %%
import os
from google.colab import userdata

os.environ["HF_TOKEN"] = userdata.get("HF_TOKEN")
os.environ["ROBOFLOW_API_KEY"] = userdata.get("ROBOFLOW_API_KEY")

# %% [markdown]
# ### Check GPU availability
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `T4 GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Tue Mar 25 20:33:58 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   46C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ### Install dependencies

# %%
# !pip install -q rfdetr
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.3/266.3 kB 15.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.0/122.0 kB 10.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 109.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 84.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 52.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 867.9 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 90.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 103.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.9/57.9 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 80.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 75.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 354.9/354.9 kB 29.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.5/181.5 kB 15.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 kB 8.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 13.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.7/220.7 kB 19.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 112.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 765.5/765.5 kB 50.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 71.0 MB/s eta 0:00:00
#   Building wheel for fairscale (pyproject.toml) ... done

# %% [markdown]
# ### Download example data

# %%
# !wget -q https://media.roboflow.com/notebooks/examples/dog-2.jpeg
# !wget -q https://media.roboflow.com/notebooks/examples/dog-3.jpeg

# %% [markdown]
# ## Inference with Pre-trained COCO Model

# %%
from rfdetr import RFDETRBase
from rfdetr.util.coco_classes import COCO_CLASSES
import supervision as sv
import numpy as np
from PIL import Image

image = Image.open("dog-2.jpeg")

model = RFDETRBase()
detections = model.predict(image, threshold=0.5)

color = sv.ColorPalette.from_hex([
    "#ffff00", "#ff9b00", "#ff8080", "#ff66b2", "#ff66ff", "#b266ff",
    "#9999ff", "#3399ff", "#66ffff", "#33ff99", "#66ff66", "#99ff00"
])
text_scale = sv.calculate_optimal_text_scale(resolution_wh=image.size)
thickness = sv.calculate_optimal_line_thickness(resolution_wh=image.size)

bbox_annotator = sv.BoxAnnotator(color=color, thickness=thickness)
label_annotator = sv.LabelAnnotator(
    color=color,
    text_color=sv.Color.BLACK,
    text_scale=text_scale,
    smart_position=True
)

labels = [
    f"{COCO_CLASSES[class_id]} {confidence:.2f}"
    for class_id, confidence
    in zip(detections.class_id, detections.confidence)
]

annotated_image = image.copy()
annotated_image = bbox_annotator.annotate(annotated_image, detections)
annotated_image = label_annotator.annotate(annotated_image, detections, labels)
annotated_image
# Out:
# Installing onnxruntime by `/usr/bin/python3 -m pip install onnxruntime`, please wait for a moment..
# rf-detr-base.pth: 100%|██████████| 355M/355M [00:16<00:00, 22.3MiB/s]
# config.json:   0%|          | 0.00/547 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/88.2M [00:00<?, ?B/s]
# Loading pretrain weights
# UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:3637.)
# <PIL.Image.Image image mode=RGB size=720x1280>

# %% [markdown]
# ## Download dataset from Roboflow Universe

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="N810XmBPyUAjLDOjTHW1")
project = rf.workspace("seagrassai").project("dugong_ai_v2")
version = project.version(1)
dataset = version.download("coco")


#dataset = download_dataset("https://universe.roboflow.com/rf100-vl/mahjong-vtacs-mexax-m4vyu-sjtd/dataset/2", "coco")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Dugong_AI_v2-1 to coco:: 100%|██████████| 310650/310650 [00:18<00:00, 16411.22it/s]
# Extracting Dataset Version Zip to Dugong_AI_v2-1 in coco:: 100%|██████████| 9086/9086 [00:01<00:00, 4836.35it/s]

# %% [markdown]
# ## Train RF-DETR on custom dataset
#
# ### Choose the right `batch_size`
#
# Different GPUs have different amounts of VRAM (video memory), which limits how much data they can handle at once during training. To make training work well on any machine, you can adjust two settings: `batch_size` and `grad_accum_steps`. These control how many samples are processed at a time. The key is to keep their product equal to 16 — that’s our recommended total batch size. For example, on powerful GPUs like the A100, set `batch_size=16` and `grad_accum_steps=1`. On smaller GPUs like the T4, use `batch_size=4` and `grad_accum_steps=4`. We use a method called gradient accumulation, which lets the model simulate training with a larger batch size by gradually collecting updates before adjusting the weights.
#
# ### Train with multiple GPUs
#
# You can fine-tune RF-DETR on multiple GPUs using PyTorch’s Distributed Data Parallel (DDP). Create a `main.py` script that initializes your model and calls `.train()` as usual than run it in terminal.
#
# ```bash
# python -m torch.distributed.launch \
#     --nproc_per_node=8 \
#     --use_env \
#     main.py
# ```
#
# Replace `8` in the `--nproc_per_node argument` with the number of GPUs you want to use. This approach creates one training process per GPU and splits the workload automatically. Note that your effective batch size is multiplied by the number of GPUs, so you may need to adjust your `batch_size` and `grad_accum_steps` to maintain the same overall batch size.

# %%
from rfdetr import RFDETRBase

model = RFDETRBase()
history = []

def callback2(data):
    history.append(data)

model.callbacks["on_fit_epoch_end"].append(callback2)

model.train(dataset_dir=dataset.location, epochs=15, batch_size=4, grad_accum_steps=4, lr=1e-4)
# Out:
# Loading pretrain weights
# WARNING:rfdetr.detr:num_classes mismatch: model has 90 classes, but your dataset has 2 classes
# reinitializing your detection head with 2 classes.
# Not using distributed mode
# git:
#   sha: N/A, status: clean, branch: N/A
#
# Namespace(num_classes=2, grad_accum_steps=4, amp=True, lr=0.0001, lr_encoder=0.00015, batch_size=4, weight_decay=0.0001, epochs=15, lr_drop=100, clip_max_norm=0.1, lr_vit_layer_decay=0.8, lr_component_decay=0.7, do_benchmark=False, dropout=0, drop_path=0.0, drop_mode='standard', drop_schedule='constant', cutoff_epoch=0, pretrained_encoder=None, pretrain_weights='rf-detr-base.pth', pretrain_exclude_keys=None, pretrain_keys_modify_to_load=None, pretrained_distiller=None, encoder='dinov2_windowed_small', vit_encoder_num_layers=12, window_block_indexes=None, position_embedding='sine', out_feature_indexes=[2, 5, 8, 11], freeze_encoder=False, layer_norm=True, rms_norm=False, backbone_lora=False, force_no_pretrain=False, dec_layers=3, dim_feedforward=2048, hidden_dim=256, sa_nheads=8, ca_nheads=16, num_queries=300, group_detr=13, two_stage=True, projector_scale=['P4'], lite_refpoint_refine=True, num_select=300, dec_n_points=2, decoder_norm='LN', bbox_reparam=True, freeze_batch_norm=False, set_cost_class=2, set_cost_bbox=5, set_cost_giou=2, cls_loss_coef=1.0, bbox_loss_coef=5, giou_loss_coef=2, focal_alpha=0.25, aux_loss=True, sum_group_losses=False, use_varifocal_loss=False, use_position_supervised_loss=False, ia_bce_loss=True, dataset_file='roboflow', coco_path=None, dataset_dir='/content/Dugong_AI_v2-1', square_resize_div_64=True, output_dir='output', dont_save_weights=False, checkpoint_interval=10, seed=42, resume='', start_epoch=0, eval=False, use_ema=True, ema_decay=0.993, ema_tau=100, num_workers=2, device='cuda', world_size=1, dist_url='env://', sync_bn=True, fp16_eval=False, encoder_only=False, backbone_only=False, resolution=560, use_cls_token=False, multi_scale=True, expanded_scales=True, warmup_epochs=0, lr_scheduler='step', lr_min_factor=0.0, distributed=False)
# number of params: 31854308
# [392, 448, 504, 560, 616, 672, 728, 784]
# loading annotations into memory...
# Done (t=0.44s)
# creating index...
# index created!
# [392, 448, 504, 560, 616, 672, 728, 784]
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Get benchmark
# Start training
# Grad accum steps:  4
# Total batch size:  16
# LENGTH OF DATA LOADER: 472
# `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
# `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# Epoch: [0]  [  0/472]  eta: 1:14:29  lr: 0.000100  class_error: 80.00  loss: 19.1301 (19.1301)  loss_ce: 0.6640 (0.6640)  loss_bbox: 2.4091 (2.4091)  loss_giou: 1.5760 (1.5760)  loss_ce_0: 0.6012 (0.6012)  loss_bbox_0: 2.5949 (2.5949)  loss_giou_0: 1.6980 (1.6980)  loss_ce_1: 0.6640 (0.6640)  loss_bbox_1: 2.4119 (2.4119)  loss_giou_1: 1.5803 (1.5803)  loss_ce_enc: 0.5941 (0.5941)  loss_bbox_enc: 2.6226 (2.6226)  loss_giou_enc: 1.7139 (1.7139)  loss_ce_unscaled: 0.6640 (0.6640)  class_error_unscaled: 80.0000 (80.0000)  loss_bbox_unscaled: 0.4818 (0.4818)  loss_giou_unscaled: 0.7880 (0.7880)  cardinality_error_unscaled: 2237.2500 (2237.2500)  loss_ce_0_unscaled: 0.6012 (0.6012)  loss_bbox_0_unscaled: 0.5190 (0.5190)  loss_giou_0_unscaled: 0.8490 (0.8490)  cardinality_error_0_unscaled: 1711.5000 (1711.5000)  loss_ce_1_unscaled: 0.6640 (0.6640)  loss_bbox_1_unscaled: 0.4824 (0.4824)  loss_giou_1_unscaled: 0.7902 (0.7902)  cardinality_error_1_unscaled: 2187.7500 (2187.7500)  loss_ce_enc_unscaled: 0.5941 (0.5941)  loss_bbox_enc_unscaled: 0.5245 (0.5245)  loss_giou_enc_unscaled: 0.8569 (0.8569)  cardinality_error_enc_unscaled: 2329.0000 (2329.0000)  time: 9.4687  data: 1.6581  max mem: 8997
# Epoch: [0]  [ 10/472]  eta: 0:54:29  lr: 0.000100  class_error: 16.92  loss: 17.4973 (17.6111)  loss_ce: 0.8091 (0.7776)  loss_bbox: 2.0736 (2.1147)  loss_giou: 1.4084 (1.4272)  loss_ce_0: 0.7668 (0.7418)  loss_bbox_0: 2.1577 (2.2207)  loss_giou_0: 1.4733 (1.4939)  loss_ce_1: 0.7665 (0.7640)  loss_bbox_1: 2.0817 (2.1393)  loss_giou_1: 1.4045 (1.4470)  loss_ce_enc: 0.7149 (0.7163)  loss_bbox_enc: 2.2166 (2.2404)  loss_giou_enc: 1.4851 (1.5282)  loss_ce_unscaled: 0.8091 (0.7776)  class_error_unscaled: 58.4615 (58.4982)  loss_bbox_unscaled: 0.4147 (0.4229)  loss_giou_unscaled: 0.7042 (0.7136)  cardinality_error_unscaled: 1890.7500 (1847.3409)  loss_ce_0_unscaled: 0.7668 (0.7418)  loss_bbox_0_unscaled: 0.4315 (0.4441)  loss_giou_0_unscaled: 0.7367 (0.7470)  cardinality_error_0_unscaled: 716.2500 (779.8636)  loss_ce_1_unscaled: 0.7665 (0.7640)  loss_bbox_1_unscaled: 0.4163 (0.4279)  loss_giou_1_unscaled: 0.7023 (0.7235)  cardinality_error_1_unscaled: 1427.5000 (1350.0682)  loss_ce_enc_unscaled: 0.7149 (0.7163)  loss_bbox_enc_unscaled: 0.4433 (0.4481)  loss_giou_enc_unscaled: 0.7426 (0.7641)  cardinality_error_enc_unscaled: 1826.2500 (1832.9545)  time: 7.0761  data: 0.1935  max mem: 9232
# Epoch: [0]  [ 20/472]  eta: 0:52:57  lr: 0.000100  class_error: 0.00  loss: 16.2152 (16.4526)  loss_ce: 0.8663 (0.8368)  loss_bbox: 1.8354 (1.8957)  loss_giou: 1.2616 (1.2871)  loss_ce_0: 0.8259 (0.8093)  loss_bbox_0: 1.9402 (1.9859)  loss_giou_0: 1.3476 (1.3595)  loss_ce_1: 0.8669 (0.8324)  loss_bbox_1: 1.8478 (1.9047)  loss_giou_1: 1.2807 (1.2980)  loss_ce_enc: 0.7861 (0.7755)  loss_bbox_enc: 1.9598 (2.0522)  loss_giou_enc: 1.3926 (1.4157)  loss_ce_unscaled: 0.8663 (0.8368)  class_error_unscaled: 4.3956 (31.1076)  loss_bbox_unscaled: 0.3671 (0.3791)  loss_giou_unscaled: 0.6308 (0.6435)  cardinality_error_unscaled: 490.0000 (1014.1190)  loss_ce_0_unscaled: 0.8259 (0.8093)  loss_bbox_0_unscaled: 0.3880 (0.3972)  loss_giou_0_unscaled: 0.6738 (0.6797)  cardinality_error_0_unscaled: 12.5000 (410.6667)  loss_ce_1_unscaled: 0.8669 (0.8324)  loss_bbox_1_unscaled: 0.3696 (0.3809)  loss_giou_1_unscaled: 0.6403 (0.6490)  cardinality_error_1_unscaled: 490.0000 (800.6429)  loss_ce_enc_unscaled: 0.7861 (0.7755)  loss_bbox_enc_unscaled: 0.3920 (0.4104)  loss_giou_enc_unscaled: 0.6963 (0.7078)  cardinality_error_enc_unscaled: 1208.7500 (1425.1667)  time: 6.9087  data: 0.0510  max mem: 9232
# Epoch: [0]  [ 30/472]  eta: 0:51:33  lr: 0.000100  class_error: 0.00  loss: 11.3638 (14.5721)  loss_ce: 0.9355 (0.8892)  loss_bbox: 0.9176 (1.5538)  loss_giou: 0.8681 (1.1039)  loss_ce_0: 0.9707 (0.9106)  loss_bbox_0: 0.9548 (1.6281)  loss_giou_0: 0.9147 (1.1555)  loss_ce_1: 0.9928 (0.9058)  loss_bbox_1: 0.9525 (1.5468)  loss_giou_1: 0.8121 (1.1026)  loss_ce_enc: 0.9578 (0.8640)  loss_bbox_enc: 1.1007 (1.6917)  loss_giou_enc: 0.9615 (1.2202)  loss_ce_unscaled: 0.9355 (0.8892)  class_error_unscaled: 0.0000 (21.0729)  loss_bbox_unscaled: 0.1835 (0.3108)  loss_giou_unscaled: 0.4340 (0.5519)  cardinality_error_unscaled: 1.5000 (687.4032)  loss_ce_0_unscaled: 0.9707 (0.9106)  loss_bbox_0_unscaled: 0.1910 (0.3256)  loss_giou_0_unscaled: 0.4573 (0.5777)  cardinality_error_0_unscaled: 1.7500 (278.7500)  loss_ce_1_unscaled: 0.9928 (0.9058)  loss_bbox_1_unscaled: 0.1905 (0.3094)  loss_giou_1_unscaled: 0.4060 (0.5513)  cardinality_error_1_unscaled: 1.5000 (542.7661)  loss_ce_enc_unscaled: 0.9578 (0.8640)  loss_bbox_enc_unscaled: 0.2201 (0.3383)  loss_giou_enc_unscaled: 0.4807 (0.6101)  cardinality_error_enc_unscaled: 760.0000 (1095.6371)  time: 6.9571  data: 0.0584  max mem: 9232
# Epoch: [0]  [ 40/472]  eta: 0:50:24  lr: 0.000100  class_error: -0.00  loss: 9.9416 (13.3066)  loss_ce: 0.9470 (0.8846)  loss_bbox: 0.7501 (1.3333)  loss_giou: 0.7074 (1.0175)  loss_ce_0: 1.1367 (0.9599)  loss_bbox_0: 0.7667 (1.3791)  loss_giou_0: 0.6777 (1.0369)  loss_ce_1: 1.0323 (0.9256)  loss_bbox_1: 0.7242 (1.3160)  loss_giou_1: 0.6768 (1.0016)  loss_ce_enc: 1.0753 (0.9197)  loss_bbox_enc: 0.8393 (1.4351)  loss_giou_enc: 0.7316 (1.0972)  loss_ce_unscaled: 0.9470 (0.8846)  class_error_unscaled: 0.0000 (15.9644)  loss_bbox_unscaled: 0.1500 (0.2667)  loss_giou_unscaled: 0.3537 (0.5087)  cardinality_error_unscaled: 1.7500 (521.7073)  loss_ce_0_unscaled: 1.1367 (0.9599)  loss_bbox_0_unscaled: 0.1533 (0.2758)  loss_giou_0_unscaled: 0.3389 (0.5185)  cardinality_error_0_unscaled: 1.2500 (211.1037)  loss_ce_1_unscaled: 1.0323 (0.9256)  loss_bbox_1_unscaled: 0.1448 (0.2632)  loss_giou_1_unscaled: 0.3384 (0.5008)  cardinality_error_1_unscaled: 1.2500 (410.9329)  loss_ce_enc_unscaled: 1.0753 (0.9197)  loss_bbox_enc_unscaled: 0.1679 (0.2870)  loss_giou_enc_unscaled: 0.3658 (0.5486)  cardinality_error_enc_unscaled: 109.7500 (833.2866)  time: 6.9717  data: 0.0588  max mem: 9232
# Epoch: [0]  [ 50/472]  eta: 0:49:18  lr: 0.000100  class_error: 0.00  loss: 7.5712 (12.1167)  loss_ce: 0.7999 (0.8698)  loss_bbox: 0.4443 (1.1512)  loss_giou: 0.5653 (0.9194)  loss_ce_0: 1.2053 (1.0122)  loss_bbox_0: 0.2905 (1.1578)  loss_giou_0: 0.4144 (0.9027)  loss_ce_1: 0.9199 (0.9235)  loss_bbox_1: 0.4093 (1.1291)  loss_giou_1: 0.5348 (0.8988)  loss_ce_enc: 1.2250 (0.9855)  loss_bbox_enc: 0.3058 (1.2074)  loss_giou_enc: 0.4524 (0.9595)  loss_ce_unscaled: 0.7999 (0.8698)  class_error_unscaled: 0.0000 (12.8342)  loss_bbox_unscaled: 0.0889 (0.2302)  loss_giou_unscaled: 0.2827 (0.4597)  cardinality_error_unscaled: 10.7500 (432.0049)  loss_ce_0_unscaled: 1.2053 (1.0122)  loss_bbox_0_unscaled: 0.0581 (0.2316)  loss_giou_0_unscaled: 0.2072 (0.4513)  cardinality_error_0_unscaled: 1.2500 (169.9216)  loss_ce_1_unscaled: 0.9199 (0.9235)  loss_bbox_1_unscaled: 0.0819 (0.2258)  loss_giou_1_unscaled: 0.2674 (0.4494)  cardinality_error_1_unscaled: 3.0000 (334.0000)  loss_ce_enc_unscaled: 1.2250 (0.9855)  loss_bbox_enc_unscaled: 0.0612 (0.2415)  loss_giou_enc_unscaled: 0.2262 (0.4797)  cardinality_error_enc_unscaled: 1.2500 (670.1471)  time: 7.0277  data: 0.0545  max mem: 9232
# Epoch: [0]  [ 60/472]  eta: 0:47:57  lr: 0.000100  class_error: -0.00  loss: 7.4433 (11.5019)  loss_ce: 0.7777 (0.8496)  loss_bbox: 0.4443 (1.0595)  loss_giou: 0.5494 (0.8770)  loss_ce_0: 1.1886 (1.0298)  loss_bbox_0: 0.2815 (1.0489)  loss_giou_0: 0.3862 (0.8459)  loss_ce_1: 0.8532 (0.9043)  loss_bbox_1: 0.4021 (1.0367)  loss_giou_1: 0.5344 (0.8565)  loss_ce_enc: 1.2330 (1.0165)  loss_bbox_enc: 0.3058 (1.0853)  loss_giou_enc: 0.4150 (0.8920)  loss_ce_unscaled: 0.7777 (0.8496)  class_error_unscaled: 0.0000 (10.7302)  loss_bbox_unscaled: 0.0889 (0.2119)  loss_giou_unscaled: 0.2747 (0.4385)  cardinality_error_unscaled: 44.2500 (368.4467)  loss_ce_0_unscaled: 1.1886 (1.0298)  loss_bbox_0_unscaled: 0.0563 (0.2098)  loss_giou_0_unscaled: 0.1931 (0.4230)  cardinality_error_0_unscaled: 1.2500 (142.2992)  loss_ce_1_unscaled: 0.8532 (0.9043)  loss_bbox_1_unscaled: 0.0804 (0.2073)  loss_giou_1_unscaled: 0.2672 (0.4283)  cardinality_error_1_unscaled: 16.2500 (282.3730)  loss_ce_enc_unscaled: 1.2330 (1.0165)  loss_bbox_enc_unscaled: 0.0612 (0.2171)  loss_giou_enc_unscaled: 0.2075 (0.4460)  cardinality_error_enc_unscaled: 1.2500 (560.5328)  time: 6.9470  data: 0.0536  max mem: 9232
# Epoch: [0]  [ 70/472]  eta: 0:46:52  lr: 0.000100  class_error: -0.00  loss: 7.9656 (10.9836)  loss_ce: 0.7701 (0.8419)  loss_bbox: 0.5268 (0.9837)  loss_giou: 0.5735 (0.8394)  loss_ce_0: 1.1259 (1.0431)  loss_bbox_0: 0.3184 (0.9503)  loss_giou_0: 0.4099 (0.7911)  loss_ce_1: 0.8170 (0.8943)  loss_bbox_1: 0.5177 (0.9619)  loss_giou_1: 0.5461 (0.8199)  loss_ce_enc: 1.2272 (1.0466)  loss_bbox_enc: 0.3226 (0.9808)  loss_giou_enc: 0.4307 (0.8306)  loss_ce_unscaled: 0.7701 (0.8419)  class_error_unscaled: 0.0000 (9.2189)  loss_bbox_unscaled: 0.1054 (0.1967)  loss_giou_unscaled: 0.2867 (0.4197)  cardinality_error_unscaled: 41.0000 (323.9648)  loss_ce_0_unscaled: 1.1259 (1.0431)  loss_bbox_0_unscaled: 0.0637 (0.1901)  loss_giou_0_unscaled: 0.2049 (0.3956)  cardinality_error_0_unscaled: 1.2500 (122.4366)  loss_ce_1_unscaled: 0.8170 (0.8943)  loss_bbox_1_unscaled: 0.1035 (0.1924)  loss_giou_1_unscaled: 0.2730 (0.4100)  cardinality_error_1_unscaled: 13.7500 (244.2606)  loss_ce_enc_unscaled: 1.2272 (1.0466)  loss_bbox_enc_unscaled: 0.0645 (0.1962)  loss_giou_enc_unscaled: 0.2153 (0.4153)  cardinality_error_enc_unscaled: 1.2500 (481.7676)  time: 6.9633  data: 0.0538  max mem: 9232
# Epoch: [0]  [ 80/472]  eta: 0:45:47  lr: 0.000100  class_error: 0.00  loss: 7.7965 (10.5662)  loss_ce: 0.7538 (0.8254)  loss_bbox: 0.4824 (0.9254)  loss_giou: 0.5955 (0.8085)  loss_ce_0: 1.0472 (1.0407)  loss_bbox_0: 0.3184 (0.8874)  loss_giou_0: 0.4099 (0.7547)  loss_ce_1: 0.8033 (0.8776)  loss_bbox_1: 0.4794 (0.9030)  loss_giou_1: 0.5979 (0.7887)  loss_ce_enc: 1.2108 (1.0638)  loss_bbox_enc: 0.3065 (0.9058)  loss_giou_enc: 0.4011 (0.7850)  loss_ce_unscaled: 0.7538 (0.8254)  class_error_unscaled: 0.0000 (8.0808)  loss_bbox_unscaled: 0.0965 (0.1851)  loss_giou_unscaled: 0.2977 (0.4043)  cardinality_error_unscaled: 39.0000 (288.0123)  loss_ce_0_unscaled: 1.0472 (1.0407)  loss_bbox_0_unscaled: 0.0637 (0.1775)  loss_giou_0_unscaled: 0.2049 (0.3774)  cardinality_error_0_unscaled: 1.2500 (107.4846)  loss_ce_1_unscaled: 0.8033 (0.8776)  loss_bbox_1_unscaled: 0.0959 (0.1806)  loss_giou_1_unscaled: 0.2990 (0.3944)  cardinality_error_1_unscaled: 5.0000 (214.7315)  loss_ce_enc_unscaled: 1.2108 (1.0638)  loss_bbox_enc_unscaled: 0.0613 (0.1812)  loss_giou_enc_unscaled: 0.2005 (0.3925)  cardinality_error_enc_unscaled: 1.2500 (422.4537)  time: 7.0815  data: 0.0524  max mem: 9232
# Epoch: [0]  [ 90/472]  eta: 0:44:40  lr: 0.000100  class_error: 0.00  loss: 6.5118 (10.1190)  loss_ce: 0.6704 (0.8075)  loss_bbox: 0.4139 (0.8649)  loss_giou: 0.4875 (0.7689)  loss_ce_0: 0.9940 (1.0300)  loss_bbox_0: 0.3144 (0.8275)  loss_giou_0: 0.4066 (0.7173)  loss_ce_1: 0.7326 (0.8589)  loss_bbox_1: 0.3857 (0.8443)  loss_giou_1: 0.4894 (0.7508)  loss_ce_enc: 1.1784 (1.0746)  loss_bbox_enc: 0.2535 (0.8361)  loss_giou_enc: 0.3290 (0.7382)  loss_ce_unscaled: 0.6704 (0.8075)  class_error_unscaled: 0.0000 (7.1928)  loss_bbox_unscaled: 0.0828 (0.1730)  loss_giou_unscaled: 0.2437 (0.3844)  cardinality_error_unscaled: 16.7500 (258.4451)  loss_ce_0_unscaled: 0.9940 (1.0300)  loss_bbox_0_unscaled: 0.0629 (0.1655)  loss_giou_0_unscaled: 0.2033 (0.3587)  cardinality_error_0_unscaled: 1.2500 (95.8242)  loss_ce_1_unscaled: 0.7326 (0.8589)  loss_bbox_1_unscaled: 0.0771 (0.1689)  loss_giou_1_unscaled: 0.2447 (0.3754)  cardinality_error_1_unscaled: 2.7500 (191.3984)  loss_ce_enc_unscaled: 1.1784 (1.0746)  loss_bbox_enc_unscaled: 0.0507 (0.1672)  loss_giou_enc_unscaled: 0.1645 (0.3691)  cardinality_error_enc_unscaled: 1.2500 (376.1841)  time: 7.0930  data: 0.0514  max mem: 9232
# Epoch: [0]  [100/472]  eta: 0:43:30  lr: 0.000100  class_error: 0.00  loss: 6.4099 (9.7608)  loss_ce: 0.6366 (0.7915)  loss_bbox: 0.3726 (0.8193)  loss_giou: 0.4721 (0.7398)  loss_ce_0: 0.9204 (1.0160)  loss_bbox_0: 0.2949 (0.7784)  loss_giou_0: 0.3739 (0.6873)  loss_ce_1: 0.6802 (0.8432)  loss_bbox_1: 0.3523 (0.7976)  loss_giou_1: 0.4531 (0.7207)  loss_ce_enc: 1.1275 (1.0784)  loss_bbox_enc: 0.2513 (0.7833)  loss_giou_enc: 0.3376 (0.7052)  loss_ce_unscaled: 0.6366 (0.7915)  class_error_unscaled: 0.0000 (6.4806)  loss_bbox_unscaled: 0.0745 (0.1639)  loss_giou_unscaled: 0.2361 (0.3699)  cardinality_error_unscaled: 16.0000 (235.2673)  loss_ce_0_unscaled: 0.9204 (1.0160)  loss_bbox_0_unscaled: 0.0590 (0.1557)  loss_giou_0_unscaled: 0.1869 (0.3437)  cardinality_error_0_unscaled: 1.5000 (86.4876)  loss_ce_1_unscaled: 0.6802 (0.8432)  loss_bbox_1_unscaled: 0.0705 (0.1595)  loss_giou_1_unscaled: 0.2266 (0.3604)  cardinality_error_1_unscaled: 1.7500 (172.6040)  loss_ce_enc_unscaled: 1.1275 (1.0784)  loss_bbox_enc_unscaled: 0.0503 (0.1567)  loss_giou_enc_unscaled: 0.1688 (0.3526)  cardinality_error_enc_unscaled: 1.2500 (339.0619)  time: 7.0502  data: 0.0519  max mem: 9232
# Epoch: [0]  [110/472]  eta: 0:42:16  lr: 0.000100  class_error: 0.00  loss: 6.3710 (9.4788)  loss_ce: 0.6194 (0.7765)  loss_bbox: 0.3977 (0.7831)  loss_giou: 0.4786 (0.7196)  loss_ce_0: 0.8680 (0.9985)  loss_bbox_0: 0.2949 (0.7442)  loss_giou_0: 0.3970 (0.6690)  loss_ce_1: 0.6607 (0.8249)  loss_bbox_1: 0.3770 (0.7634)  loss_giou_1: 0.4558 (0.7009)  loss_ce_enc: 1.0778 (1.0751)  loss_bbox_enc: 0.2993 (0.7429)  loss_giou_enc: 0.3442 (0.6809)  loss_ce_unscaled: 0.6194 (0.7765)  class_error_unscaled: 0.0000 (5.8968)  loss_bbox_unscaled: 0.0795 (0.1566)  loss_giou_unscaled: 0.2393 (0.3598)  cardinality_error_unscaled: 18.5000 (215.9414)  loss_ce_0_unscaled: 0.8680 (0.9985)  loss_bbox_0_unscaled: 0.0590 (0.1488)  loss_giou_0_unscaled: 0.1985 (0.3345)  cardinality_error_0_unscaled: 1.2500 (78.8108)  loss_ce_1_unscaled: 0.6607 (0.8249)  loss_bbox_1_unscaled: 0.0754 (0.1527)  loss_giou_1_unscaled: 0.2279 (0.3504)  cardinality_error_1_unscaled: 2.2500 (157.4032)  loss_ce_enc_unscaled: 1.0778 (1.0751)  loss_bbox_enc_unscaled: 0.0599 (0.1486)  loss_giou_enc_unscaled: 0.1721 (0.3404)  cardinality_error_enc_unscaled: 1.2500 (308.6239)  time: 6.9538  data: 0.0524  max mem: 9232
# Epoch: [0]  [120/472]  eta: 0:41:06  lr: 0.000100  class_error: 0.00  loss: 6.3710 (9.2771)  loss_ce: 0.6188 (0.7694)  loss_bbox: 0.3932 (0.7548)  loss_giou: 0.4627 (0.7048)  loss_ce_0: 0.7782 (0.9801)  loss_bbox_0: 0.3756 (0.7211)  loss_giou_0: 0.4625 (0.6594)  loss_ce_1: 0.6350 (0.8149)  loss_bbox_1: 0.3931 (0.7371)  loss_giou_1: 0.4549 (0.6881)  loss_ce_enc: 1.0001 (1.0657)  loss_bbox_enc: 0.3054 (0.7148)  loss_giou_enc: 0.3981 (0.6669)  loss_ce_unscaled: 0.6188 (0.7694)  class_error_unscaled: 0.0000 (5.4094)  loss_bbox_unscaled: 0.0786 (0.1510)  loss_giou_unscaled: 0.2314 (0.3524)  cardinality_error_unscaled: 23.5000 (200.8843)  loss_ce_0_unscaled: 0.7782 (0.9801)  loss_bbox_0_unscaled: 0.0751 (0.1442)  loss_giou_0_unscaled: 0.2313 (0.3297)  cardinality_error_0_unscaled: 1.2500 (72.4029)  loss_ce_1_unscaled: 0.6350 (0.8149)  loss_bbox_1_unscaled: 0.0786 (0.1474)  loss_giou_1_unscaled: 0.2275 (0.3440)  cardinality_error_1_unscaled: 3.7500 (144.7893)  loss_ce_enc_unscaled: 1.0001 (1.0657)  loss_bbox_enc_unscaled: 0.0611 (0.1430)  loss_giou_enc_unscaled: 0.1991 (0.3335)  cardinality_error_enc_unscaled: 1.2500 (283.2273)  time: 6.9552  data: 0.0532  max mem: 9232
# Epoch: [0]  [130/472]  eta: 0:39:58  lr: 0.000100  class_error: 0.00  loss: 6.1253 (9.0486)  loss_ce: 0.5894 (0.7568)  loss_bbox: 0.3633 (0.7291)  loss_giou: 0.4627 (0.6877)  loss_ce_0: 0.6942 (0.9584)  loss_bbox_0: 0.3770 (0.6972)  loss_giou_0: 0.4625 (0.6445)  loss_ce_1: 0.5931 (0.7992)  loss_bbox_1: 0.3772 (0.7121)  loss_giou_1: 0.4549 (0.6717)  loss_ce_enc: 0.9333 (1.0550)  loss_bbox_enc: 0.3334 (0.6869)  loss_giou_enc: 0.4334 (0.6501)  loss_ce_unscaled: 0.5894 (0.7568)  class_error_unscaled: 0.0000 (4.9965)  loss_bbox_unscaled: 0.0727 (0.1458)  loss_giou_unscaled: 0.2314 (0.3438)  cardinality_error_unscaled: 35.0000 (189.0057)  loss_ce_0_unscaled: 0.6942 (0.9584)  loss_bbox_0_unscaled: 0.0754 (0.1394)  loss_giou_0_unscaled: 0.2313 (0.3222)  cardinality_error_0_unscaled: 1.2500 (66.9676)  loss_ce_1_unscaled: 0.5931 (0.7992)  loss_bbox_1_unscaled: 0.0754 (0.1424)  loss_giou_1_unscaled: 0.2275 (0.3359)  cardinality_error_1_unscaled: 7.0000 (134.9389)  loss_ce_enc_unscaled: 0.9333 (1.0550)  loss_bbox_enc_unscaled: 0.0667 (0.1374)  loss_giou_enc_unscaled: 0.2167 (0.3250)  cardinality_error_enc_unscaled: 1.2500 (261.7042)  time: 7.0482  data: 0.0524  max mem: 9232
# Epoch: [0]  [140/472]  eta: 0:38:43  lr: 0.000100  class_error: 0.00  loss: 5.8376 (8.8341)  loss_ce: 0.5752 (0.7442)  loss_bbox: 0.3669 (0.7056)  loss_giou: 0.4358 (0.6716)  loss_ce_0: 0.6811 (0.9397)  loss_bbox_0: 0.3685 (0.6736)  loss_giou_0: 0.4374 (0.6297)  loss_ce_1: 0.5869 (0.7855)  loss_bbox_1: 0.3548 (0.6896)  loss_giou_1: 0.4273 (0.6565)  loss_ce_enc: 0.8992 (1.0414)  loss_bbox_enc: 0.3354 (0.6627)  loss_giou_enc: 0.4161 (0.6342)  loss_ce_unscaled: 0.5752 (0.7442)  class_error_unscaled: 0.0000 (4.6421)  loss_bbox_unscaled: 0.0734 (0.1411)  loss_giou_unscaled: 0.2179 (0.3358)  cardinality_error_unscaled: 52.0000 (181.1383)  loss_ce_0_unscaled: 0.6811 (0.9397)  loss_bbox_0_unscaled: 0.0737 (0.1347)  loss_giou_0_unscaled: 0.2187 (0.3149)  cardinality_error_0_unscaled: 1.0000 (62.3191)  loss_ce_1_unscaled: 0.5869 (0.7855)  loss_bbox_1_unscaled: 0.0710 (0.1379)  loss_giou_1_unscaled: 0.2136 (0.3282)  cardinality_error_1_unscaled: 14.0000 (126.6773)  loss_ce_enc_unscaled: 0.8992 (1.0414)  loss_bbox_enc_unscaled: 0.0671 (0.1325)  loss_giou_enc_unscaled: 0.2081 (0.3171)  cardinality_error_enc_unscaled: 1.0000 (243.2287)  time: 6.9537  data: 0.0519  max mem: 9232
# Epoch: [0]  [150/472]  eta: 0:37:33  lr: 0.000100  class_error: 0.00  loss: 6.2129 (8.6949)  loss_ce: 0.6213 (0.7373)  loss_bbox: 0.4202 (0.6908)  loss_giou: 0.4800 (0.6615)  loss_ce_0: 0.7359 (0.9260)  loss_bbox_0: 0.3713 (0.6581)  loss_giou_0: 0.4540 (0.6201)  loss_ce_1: 0.6251 (0.7772)  loss_bbox_1: 0.4024 (0.6752)  loss_giou_1: 0.4691 (0.6469)  loss_ce_enc: 0.8684 (1.0298)  loss_bbox_enc: 0.3625 (0.6472)  loss_giou_enc: 0.4237 (0.6247)  loss_ce_unscaled: 0.6213 (0.7373)  class_error_unscaled: 0.0000 (4.3347)  loss_bbox_unscaled: 0.0840 (0.1382)  loss_giou_unscaled: 0.2400 (0.3308)  cardinality_error_unscaled: 58.0000 (172.9818)  loss_ce_0_unscaled: 0.7359 (0.9260)  loss_bbox_0_unscaled: 0.0743 (0.1316)  loss_giou_0_unscaled: 0.2270 (0.3101)  cardinality_error_0_unscaled: 1.0000 (58.2781)  loss_ce_1_unscaled: 0.6251 (0.7772)  loss_bbox_1_unscaled: 0.0805 (0.1350)  loss_giou_1_unscaled: 0.2346 (0.3234)  cardinality_error_1_unscaled: 8.2500 (118.5877)  loss_ce_enc_unscaled: 0.8684 (1.0298)  loss_bbox_enc_unscaled: 0.0725 (0.1294)  loss_giou_enc_unscaled: 0.2118 (0.3124)  cardinality_error_enc_unscaled: 1.2500 (227.2119)  time: 6.9019  data: 0.0531  max mem: 9232
# Epoch: [0]  [160/472]  eta: 0:36:23  lr: 0.000100  class_error: 0.00  loss: 6.9053 (8.5930)  loss_ce: 0.6408 (0.7328)  loss_bbox: 0.4506 (0.6758)  loss_giou: 0.5563 (0.6550)  loss_ce_0: 0.7470 (0.9144)  loss_bbox_0: 0.3713 (0.6455)  loss_giou_0: 0.5166 (0.6171)  loss_ce_1: 0.6471 (0.7705)  loss_bbox_1: 0.4379 (0.6620)  loss_giou_1: 0.5541 (0.6423)  loss_ce_enc: 0.8400 (1.0180)  loss_bbox_enc: 0.4196 (0.6363)  loss_giou_enc: 0.5217 (0.6233)  loss_ce_unscaled: 0.6408 (0.7328)  class_error_unscaled: 0.0000 (4.0655)  loss_bbox_unscaled: 0.0901 (0.1352)  loss_giou_unscaled: 0.2781 (0.3275)  cardinality_error_unscaled: 47.5000 (165.9348)  loss_ce_0_unscaled: 0.7470 (0.9144)  loss_bbox_0_unscaled: 0.0743 (0.1291)  loss_giou_0_unscaled: 0.2583 (0.3086)  cardinality_error_0_unscaled: 1.5000 (54.7764)  loss_ce_1_unscaled: 0.6471 (0.7705)  loss_bbox_1_unscaled: 0.0876 (0.1324)  loss_giou_1_unscaled: 0.2771 (0.3211)  cardinality_error_1_unscaled: 5.7500 (111.9534)  loss_ce_enc_unscaled: 0.8400 (1.0180)  loss_bbox_enc_unscaled: 0.0839 (0.1273)  loss_giou_enc_unscaled: 0.2609 (0.3116)  cardinality_error_enc_unscaled: 1.5000 (213.1925)  time: 6.9980  data: 0.0529  max mem: 9232
# Epoch: [0]  [170/472]  eta: 0:35:11  lr: 0.000100  class_error: 0.00  loss: 6.4065 (8.4593)  loss_ce: 0.6408 (0.7279)  loss_bbox: 0.3836 (0.6592)  loss_giou: 0.4943 (0.6446)  loss_ce_0: 0.7097 (0.9024)  loss_bbox_0: 0.3658 (0.6298)  loss_giou_0: 0.4819 (0.6078)  loss_ce_1: 0.6344 (0.7637)  loss_bbox_1: 0.3813 (0.6464)  loss_giou_1: 0.4982 (0.6326)  loss_ce_enc: 0.8035 (1.0053)  loss_bbox_enc: 0.4404 (0.6233)  loss_giou_enc: 0.5202 (0.6163)  loss_ce_unscaled: 0.6408 (0.7279)  class_error_unscaled: 0.0000 (3.8277)  loss_bbox_unscaled: 0.0767 (0.1318)  loss_giou_unscaled: 0.2472 (0.3223)  cardinality_error_unscaled: 42.7500 (158.4664)  loss_ce_0_unscaled: 0.7097 (0.9024)  loss_bbox_0_unscaled: 0.0732 (0.1260)  loss_giou_0_unscaled: 0.2409 (0.3039)  cardinality_error_0_unscaled: 1.5000 (51.6623)  loss_ce_1_unscaled: 0.6344 (0.7637)  loss_bbox_1_unscaled: 0.0763 (0.1293)  loss_giou_1_unscaled: 0.2491 (0.3163)  cardinality_error_1_unscaled: 16.0000 (106.6462)  loss_ce_enc_unscaled: 0.8035 (1.0053)  loss_bbox_enc_unscaled: 0.0881 (0.1247)  loss_giou_enc_unscaled: 0.2601 (0.3081)  cardinality_error_enc_unscaled: 1.5000 (200.8216)  time: 6.9423  data: 0.0522  max mem: 9232
# Epoch: [0]  [180/472]  eta: 0:34:03  lr: 0.000100  class_error: 0.00  loss: 6.4065 (8.3775)  loss_ce: 0.6262 (0.7239)  loss_bbox: 0.4306 (0.6509)  loss_giou: 0.4876 (0.6386)  loss_ce_0: 0.6782 (0.8917)  loss_bbox_0: 0.4331 (0.6227)  loss_giou_0: 0.4819 (0.6033)  loss_ce_1: 0.6309 (0.7577)  loss_bbox_1: 0.4373 (0.6390)  loss_giou_1: 0.4914 (0.6274)  loss_ce_enc: 0.7708 (0.9933)  loss_bbox_enc: 0.4644 (0.6168)  loss_giou_enc: 0.4849 (0.6122)  loss_ce_unscaled: 0.6262 (0.7239)  class_error_unscaled: 0.0000 (3.6163)  loss_bbox_unscaled: 0.0861 (0.1302)  loss_giou_unscaled: 0.2438 (0.3193)  cardinality_error_unscaled: 24.0000 (150.8950)  loss_ce_0_unscaled: 0.6782 (0.8917)  loss_bbox_0_unscaled: 0.0866 (0.1245)  loss_giou_0_unscaled: 0.2409 (0.3017)  cardinality_error_0_unscaled: 1.2500 (48.8771)  loss_ce_1_unscaled: 0.6309 (0.7577)  loss_bbox_1_unscaled: 0.0875 (0.1278)  loss_giou_1_unscaled: 0.2457 (0.3137)  cardinality_error_1_unscaled: 24.0000 (102.6077)  loss_ce_enc_unscaled: 0.7708 (0.9933)  loss_bbox_enc_unscaled: 0.0929 (0.1234)  loss_giou_enc_unscaled: 0.2424 (0.3061)  cardinality_error_enc_unscaled: 1.2500 (189.7956)  time: 6.9860  data: 0.0522  max mem: 9232
# Epoch: [0]  [190/472]  eta: 0:32:53  lr: 0.000100  class_error: 0.00  loss: 6.5819 (8.2767)  loss_ce: 0.6382 (0.7192)  loss_bbox: 0.4173 (0.6390)  loss_giou: 0.5036 (0.6313)  loss_ce_0: 0.6706 (0.8808)  loss_bbox_0: 0.4287 (0.6124)  loss_giou_0: 0.5169 (0.5980)  loss_ce_1: 0.6410 (0.7515)  loss_bbox_1: 0.4181 (0.6280)  loss_giou_1: 0.5018 (0.6209)  loss_ce_enc: 0.7484 (0.9814)  loss_bbox_enc: 0.4484 (0.6068)  loss_giou_enc: 0.5320 (0.6074)  loss_ce_unscaled: 0.6382 (0.7192)  class_error_unscaled: 0.0000 (3.4269)  loss_bbox_unscaled: 0.0835 (0.1278)  loss_giou_unscaled: 0.2518 (0.3156)  cardinality_error_unscaled: 22.0000 (144.2893)  loss_ce_0_unscaled: 0.6706 (0.8808)  loss_bbox_0_unscaled: 0.0857 (0.1225)  loss_giou_0_unscaled: 0.2585 (0.2990)  cardinality_error_0_unscaled: 1.2500 (46.3953)  loss_ce_1_unscaled: 0.6410 (0.7515)  loss_bbox_1_unscaled: 0.0836 (0.1256)  loss_giou_1_unscaled: 0.2509 (0.3105)  cardinality_error_1_unscaled: 29.7500 (98.7408)  loss_ce_enc_unscaled: 0.7484 (0.9814)  loss_bbox_enc_unscaled: 0.0897 (0.1214)  loss_giou_enc_unscaled: 0.2660 (0.3037)  cardinality_error_enc_unscaled: 1.2500 (179.9424)  time: 7.0424  data: 0.0525  max mem: 9232

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.DataFrame(history)

plt.figure(figsize=(12, 8))

plt.plot(
    df['epoch'],
    df['train_loss'],
    label='Training Loss',
    marker='o',
    linestyle='-'
)

plt.plot(
    df['epoch'],
    df['test_loss'],
    label='Validation Loss',
    marker='o',
    linestyle='--'
)

plt.title('Train/Validation Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.DataFrame(history)

df['avg_precision'] = df['test_coco_eval_bbox'].apply(lambda arr: arr[0])
df['avg_recall'] = df['test_coco_eval_bbox'].apply(lambda arr: arr[6])

plt.figure(figsize=(12, 8))
plt.plot(
    df['epoch'],
    df['avg_precision'],
    marker='o',
    linestyle='-'
)
plt.title('AP (IoU=0.50:0.95, area=all, maxDets=100) over Epochs')
plt.xlabel('Epoch')
plt.ylabel('AP')
plt.grid(True)
plt.show()


plt.figure(figsize=(12, 8))
plt.plot(
    df['epoch'],
    df['avg_recall'],
    marker='o',
    linestyle='-'
)
plt.title('AR (IoU=0.50:0.95, area=all, maxDets=1) over Epochs')
plt.xlabel('Epoch')
plt.ylabel('AR')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Run inference with fine-tuned model

# %%
import supervision as sv

ds = sv.DetectionDataset.from_coco(
    images_directory_path=f"{dataset.location}/test",
    annotations_path=f"{dataset.location}/test/_annotations.coco.json",
)

# %%
from rfdetr import RFDETRBase
import supervision as sv
from PIL import Image

path, image, annotations = ds[0]
image = Image.open(path)

detections = model.predict(image, threshold=0.5)

text_scale = sv.calculate_optimal_text_scale(resolution_wh=image.size)
thickness = sv.calculate_optimal_line_thickness(resolution_wh=image.size)

bbox_annotator = sv.BoxAnnotator(thickness=thickness)
label_annotator = sv.LabelAnnotator(
    text_color=sv.Color.BLACK,
    text_scale=text_scale,
    text_thickness=thickness,
    smart_position=True)

annotations_labels = [
    f"{ds.classes[class_id]}"
    for class_id
    in annotations.class_id
]

detections_labels = [
    f"{ds.classes[class_id]} {confidence:.2f}"
    for class_id, confidence
    in zip(detections.class_id, detections.confidence)
]

annotation_image = image.copy()
annotation_image = bbox_annotator.annotate(annotation_image, annotations)
annotation_image = label_annotator.annotate(annotation_image, annotations, annotations_labels)

detections_image = image.copy()
detections_image = bbox_annotator.annotate(detections_image, detections)
detections_image = label_annotator.annotate(detections_image, detections, detections_labels)

sv.plot_images_grid(images=[annotation_image, detections_image], grid_size=(1, 2), titles=["Annotation", "Detection"])

# %%
import supervision as sv
from rfdetr import RFDETRBase
from PIL import Image

detections_images = []

for i in range(16):
    path, image, annotations = ds[i]
    image = Image.open(path)

    detections = model.predict(image, threshold=0.5)

    text_scale = sv.calculate_optimal_text_scale(resolution_wh=image.size)
    thickness = sv.calculate_optimal_line_thickness(resolution_wh=image.size)

    bbox_annotator = sv.BoxAnnotator(thickness=thickness)
    label_annotator = sv.LabelAnnotator(
        text_color=sv.Color.BLACK,
        text_scale=text_scale,
        text_thickness=thickness,
        smart_position=True)

    detections_labels = [
        f"{ds.classes[class_id]} {confidence:.2f}"
        for class_id, confidence
        in zip(detections.class_id, detections.confidence)
    ]

    detections_image = image.copy()
    detections_image = bbox_annotator.annotate(detections_image, detections)
    detections_image = label_annotator.annotate(detections_image, detections, detections_labels)

    detections_images.append(detections_image)

sv.plot_images_grid(images=detections_images, grid_size=(4, 4))

# %% [markdown]
# ## Evaluate fine-tuned model

# %%
import supervision as sv
from tqdm import tqdm
from supervision.metrics import MeanAveragePrecision

targets = []
predictions = []

for path, image, annotations in tqdm(ds):
    image = Image.open(path)
    detections = model.predict(image, threshold=0.5)

    targets.append(annotations)
    predictions.append(detections)
# Out:
# 100%|██████████| 214/214 [00:56<00:00,  3.81it/s]

# %%
map_metric = MeanAveragePrecision()
map_result = map_metric.update(predictions, targets).compute()

map_result.plot()

# %%
confusion_matrix = sv.ConfusionMatrix.from_detections(
    predictions=predictions,
    targets=targets,
    classes=ds.classes
)

_ = confusion_matrix.plot()
